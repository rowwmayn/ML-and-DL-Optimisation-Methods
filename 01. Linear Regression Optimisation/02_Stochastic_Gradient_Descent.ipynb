# %%
import matplotlib.pyplot as plt;
import numpy as np;
import pandas as pd;
from sklearn.model_selection import train_test_split;

# %%
labels = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
    'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'
];
df = pd.read_csv(r"F:\Personal Projects\ML-and-DL-Optimisation-Methods\Datasets\housing.csv", sep=r"\s+", header=None, encoding="utf-8", engine='python');
df_clone = df.copy();
df_clone.columns = labels;
#print(df_clone.head(10));



df = df.to_numpy();
ones = np.ones((df.shape[0],1));
df_designed=np.hstack((ones, df));
row,col = df_designed.shape;
#print(epoch,col);
#print(df_designed.shape);
X = df_designed[:,0:df_designed.shape[1]-1];
#print(X[0][-1])
Y = df_designed[:,df_designed.shape[1]-1].reshape(row,1);
#print(Y.shape);
#print(Y);



# Initialisations!
grad = np.zeros(Y.shape); 
#li = [i for i in range(506)];
random_int = np.random.randint(0,row);
#print(random_int);
theta = [];
step_size = 0.00001;
errors = [];



train,test = train_test_split(df_designed,test_size=0.2);

# %%
print(df_designed[0]);
# Out:
# [1.000e+00 6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00
#  6.520e+01 4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00
#  2.400e+01]

# %%
epochs = [i for i in range(row)];

# %%
# 1. Initialize theta before loops
theta = np.zeros((X.shape[1], 1)); 
step_size = 0.000001; 

for e in range(100): # Epoch loop
    # 2. Use the SHUFFLED data for this pass
    shuffled_df = np.random.permutation(train);
    
    epoch_loss = 0;
    for i in range(shuffled_df.shape[0]): # Row loop
        curr = shuffled_df[i];
        
        # Features (everything but last column)
        xi = curr[:-1].reshape(1, -1); # Shape (1, 14)
        yi = curr[-1];
        
        # 3. Predict & Error
        pred_y = xi @ theta;
        error = pred_y - yi;
        
        # 4. Square the loss for monitoring
        epoch_loss += error**2;
        
        # 5. Calculate Gradient for ONE sample
        # grad = 2 * error * xi_transpose
        grad = 2 * error * xi.T; 
        
        # 6. THE CORE OF SGD: Update theta IMMEDIATELY
        theta = theta - step_size * grad;
        
    # Print average loss for this epoch
    print(f"Epoch {e}, MSE: {epoch_loss/shuffled_df.shape[0]}");
# Out:
# Epoch 0, MSE: [[124.73700809]]
# Epoch 1, MSE: [[117.39284164]]
# Epoch 2, MSE: [[132.82522459]]
# Epoch 3, MSE: [[116.00485788]]
# Epoch 4, MSE: [[117.2860503]]
# Epoch 5, MSE: [[114.1568793]]
# Epoch 6, MSE: [[107.23769081]]
# Epoch 7, MSE: [[108.71446764]]
# Epoch 8, MSE: [[117.34910708]]
# Epoch 9, MSE: [[121.44723588]]
# Epoch 10, MSE: [[102.3054575]]
# Epoch 11, MSE: [[110.96897049]]
# Epoch 12, MSE: [[97.86703052]]
# Epoch 13, MSE: [[102.26265366]]
# Epoch 14, MSE: [[106.74684675]]
# Epoch 15, MSE: [[97.0294032]]
# Epoch 16, MSE: [[108.14832263]]
# Epoch 17, MSE: [[103.06098764]]
# Epoch 18, MSE: [[96.00237917]]
# Epoch 19, MSE: [[99.35391083]]
# Epoch 20, MSE: [[91.74691018]]
# Epoch 21, MSE: [[100.37497984]]
# Epoch 22, MSE: [[92.13295794]]
# Epoch 23, MSE: [[97.84651959]]
# Epoch 24, MSE: [[100.15538289]]
# Epoch 25, MSE: [[93.79197703]]
# Epoch 26, MSE: [[97.14939228]]
# Epoch 27, MSE: [[98.76018196]]
# Epoch 28, MSE: [[88.40924823]]
# Epoch 29, MSE: [[99.31176714]]
# Epoch 30, MSE: [[91.97002048]]
# Epoch 31, MSE: [[98.44868387]]
# Epoch 32, MSE: [[88.37244045]]
# Epoch 33, MSE: [[93.02581778]]
# Epoch 34, MSE: [[88.78163329]]
# Epoch 35, MSE: [[83.80876976]]
# Epoch 36, MSE: [[89.2773322]]
# Epoch 37, MSE: [[83.84293069]]
# Epoch 38, MSE: [[92.45155085]]
# Epoch 39, MSE: [[90.45177331]]
# Epoch 40, MSE: [[90.2890174]]
# Epoch 41, MSE: [[87.62257284]]
# Epoch 42, MSE: [[86.18504822]]
# Epoch 43, MSE: [[86.35682777]]
# Epoch 44, MSE: [[89.01881489]]
# Epoch 45, MSE: [[96.69566972]]
# Epoch 46, MSE: [[89.79483925]]
# Epoch 47, MSE: [[83.10192761]]
# Epoch 48, MSE: [[85.78904118]]
# Epoch 49, MSE: [[85.59894031]]
# Epoch 50, MSE: [[87.42343514]]
# Epoch 51, MSE: [[90.77010491]]
# Epoch 52, MSE: [[86.11777026]]
# Epoch 53, MSE: [[80.38910058]]
# Epoch 54, MSE: [[83.04450202]]
# Epoch 55, MSE: [[82.63989888]]
# Epoch 56, MSE: [[76.2659238]]
# Epoch 57, MSE: [[76.277069]]
# Epoch 58, MSE: [[80.99369758]]
# Epoch 59, MSE: [[87.43929278]]
# Epoch 60, MSE: [[86.14651345]]
# Epoch 61, MSE: [[77.81051628]]
# Epoch 62, MSE: [[81.52066294]]
# Epoch 63, MSE: [[85.84990796]]
# Epoch 64, MSE: [[76.56633159]]
# Epoch 65, MSE: [[85.45970073]]
# Epoch 66, MSE: [[77.13330861]]
# Epoch 67, MSE: [[83.81687152]]
# Epoch 68, MSE: [[78.99110678]]
# Epoch 69, MSE: [[82.9066267]]
# Epoch 70, MSE: [[77.85030833]]
# Epoch 71, MSE: [[73.7937451]]
# Epoch 72, MSE: [[75.17623787]]
# Epoch 73, MSE: [[84.367419]]
# Epoch 74, MSE: [[80.19533924]]
# Epoch 75, MSE: [[78.08029344]]
# Epoch 76, MSE: [[86.02781729]]
# Epoch 77, MSE: [[74.54260888]]
# Epoch 78, MSE: [[70.61207806]]
# Epoch 79, MSE: [[74.22210488]]
# Epoch 80, MSE: [[79.14088862]]
# Epoch 81, MSE: [[85.04962064]]
# Epoch 82, MSE: [[73.91434163]]
# Epoch 83, MSE: [[79.48384792]]
# Epoch 84, MSE: [[69.2454635]]
# Epoch 85, MSE: [[77.52059095]]
# Epoch 86, MSE: [[81.59916422]]
# Epoch 87, MSE: [[79.57348448]]
# Epoch 88, MSE: [[80.12587384]]
# Epoch 89, MSE: [[70.55332742]]
# Epoch 90, MSE: [[76.88399786]]
# Epoch 91, MSE: [[73.17247576]]
# Epoch 92, MSE: [[76.1368359]]
# Epoch 93, MSE: [[79.07764645]]
# Epoch 94, MSE: [[79.98769225]]
# Epoch 95, MSE: [[76.60233586]]
# Epoch 96, MSE: [[78.23317222]]
# Epoch 97, MSE: [[75.28655246]]
# Epoch 98, MSE: [[78.26891397]]
# Epoch 99, MSE: [[76.57233366]]

# %%
print(theta);
# Out:
# [[ 0.04989186]
#  [-0.0956745 ]
#  [ 0.10379781]
#  [-0.08261545]
#  [ 0.03267355]
#  [ 0.02016602]
#  [ 0.54308728]
#  [ 0.12429394]
#  [ 0.04375698]
#  [ 0.06255329]
#  [-0.00965234]
#  [ 0.36140229]
#  [ 0.02267481]
#  [-0.75268113]]

# %%
final_pred = test[:, :-1]@theta;
final_error = final_pred - test[:,-1];
mae = np.mean(np.abs(final_error));
print(mae);
# Out:
# 8.547967929786203
